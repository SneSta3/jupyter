# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',None)

# %%
data = {'Proizvodi': ['Jabuka', 'Banana', 'Pomorandza', 'Kivi'],
        'Kolicina': [2,5,3,7]
       }

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     Proizvodi  Kolicina
# 0      Jabuka         2
# 1      Banana         5
# 2  Pomorandza         3
# 3        Kivi         7

# %% [markdown]
# ## SUM

# %%
df.sum()
# Out:
# Proizvodi    JabukaBananaPomorandzaKivi
# Kolicina                             17
# dtype: object

# %%
df['Kolicina'].sum()
# Out:
# np.int64(17)

# %% [markdown]
# ## COUNT

# %%
df.count()
# Out:
# Proizvodi    4
# Kolicina     4
# dtype: int64

# %% [markdown]
# ## MAX

# %%
df.max()
# Out:
# Proizvodi    Pomorandza
# Kolicina              7
# dtype: object

# %% [markdown]
# ## MIN

# %%
df.min()
# Out:
# Proizvodi    Banana
# Kolicina          2
# dtype: object

# %% [markdown]
# ## MEAN

# %%
df['Kolicina'].mean()
# Out:
# np.float64(4.25)

# %% [markdown]
# ## MEDIAN

# %%
df['Kolicina'].median()
# Out:
# np.float64(4.0)

# %% [markdown]
# ## 2 3 5 = 3 / 2 5 3 700 = 4 / 2 3 6 10 700 = 8

# %% [markdown]
# ## STANDARD DEVIATION

# %%
df['Kolicina'].std()
# Out:
# np.float64(2.217355782608345)

# %% [markdown]
# ## DESCRIBE

# %%
df.describe()
# Out:
#        Kolicina
# count  4.000000
# mean   4.250000
# std    2.217356
# min    2.000000
# 25%    2.750000
# 50%    4.000000
# 75%    5.500000
# max    7.000000

# %% [markdown]
# ## CORRELATION

# %%
data = { 'A': [1,2,3,4,5],
        'B': [5,4,3,2,1],
        'C': [2,3,4,5,6]
       }

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    A  B  C
# 0  1  5  2
# 1  2  4  3
# 2  3  3  4
# 3  4  2  5
# 4  5  1  6

# %%
df.corr()
# Out:
#      A    B    C
# A  1.0 -1.0  1.0
# B -1.0  1.0 -1.0
# C  1.0 -1.0  1.0

# %%
df['A'].corr(df['B'])
# Out:
# np.float64(-0.9999999999999999)

# %%
df['A'].corr(df['C'])
# Out:
# np.float64(0.9999999999999999)

# %%
df['B'].corr(df['C'])
# Out:
# np.float64(-0.9999999999999999)

# %% [markdown]
# ## GROUP BY

# %%
data = {
    'Prodavnica': ['A','A','A','A','A','A','B','B','B','B','B','B'],
    'Proizvod': ['Jabuka', 'Jabuka', 'Banana', 'Banana', 'Pomorandža', 'Pomorandža','Jabuka', 'Jabuka', 'Banana', 'Banana', 'Pomorandža', 'Pomorandža'],
    'Mesec': ['Januar', 'Februar', 'Januar', 'Februar', 'Januar', 'Februar','Januar', 'Februar', 'Januar', 'Februar', 'Januar', 'Februar'],
    'Prodaja': [100, 120, 80, 90, 70, 80, 110, 70, 130, 80,100, 90],
    'Trošak': [50, 60, 40, 45, 30, 35, 55, 50, 45, 40, 30, 40]
}
df = pd.DataFrame(data)
df
# Out:
#    Prodavnica    Proizvod    Mesec  Prodaja  Trošak
# 0           A      Jabuka   Januar      100      50
# 1           A      Jabuka  Februar      120      60
# 2           A      Banana   Januar       80      40
# 3           A      Banana  Februar       90      45
# 4           A  Pomorandža   Januar       70      30
# 5           A  Pomorandža  Februar       80      35
# 6           B      Jabuka   Januar      110      55
# 7           B      Jabuka  Februar       70      50
# 8           B      Banana   Januar      130      45
# 9           B      Banana  Februar       80      40
# 10          B  Pomorandža   Januar      100      30
# 11          B  Pomorandža  Februar       90      40

# %%
groups = df.groupby('Prodavnica')

# %%
groups

# %%
df.groupby('Prodavnica').get_group('A')
# Out:
#   Prodavnica    Proizvod    Mesec  Prodaja  Trošak
# 0          A      Jabuka   Januar      100      50
# 1          A      Jabuka  Februar      120      60
# 2          A      Banana   Januar       80      40
# 3          A      Banana  Februar       90      45
# 4          A  Pomorandža   Januar       70      30
# 5          A  Pomorandža  Februar       80      35

# %%
df.groupby('Prodavnica')['Prodaja'].mean()
# Out:
# Prodavnica
# A    90.000000
# B    96.666667
# Name: Prodaja, dtype: float64

# %%
df.groupby('Prodavnica')['Prodaja'].max()
# Out:
# Prodavnica
# A    120
# B    130
# Name: Prodaja, dtype: int64

# %%
df.groupby('Prodavnica')['Prodaja'].min()
# Out:
# Prodavnica
# A    70
# B    70
# Name: Prodaja, dtype: int64

# %%
df.groupby('Prodavnica')['Prodaja'].sum()
# Out:
# Prodavnica
# A    540
# B    580
# Name: Prodaja, dtype: int64

# %%
df.groupby('Prodavnica')['Prodaja'].count()
# Out:
# Prodavnica
# A    6
# B    6
# Name: Prodaja, dtype: int64

# %%
df.groupby(['Prodaja','Mesec'])['Trošak'].mean()
# Out:
# Prodaja  Mesec
# 70       Februar    50.0
#          Januar     30.0
# 80       Februar    37.5
#          Januar     40.0
# 90       Februar    42.5
# 100      Januar     40.0
# 110      Januar     55.0
# 120      Februar    60.0
# 130      Januar     45.0
# Name: Trošak, dtype: float64

# %%
df.groupby(['Prodaja','Mesec'])['Trošak'].mean().reset_index()
# Out:
#    Prodaja    Mesec  Trošak
# 0       70  Februar    50.0
# 1       70   Januar    30.0
# 2       80  Februar    37.5
# 3       80   Januar    40.0
# 4       90  Februar    42.5
# 5      100   Januar    40.0
# 6      110   Januar    55.0
# 7      120  Februar    60.0
# 8      130   Januar    45.0

# %%
df.groupby(['Prodaja','Mesec'])['Trošak'].mean().round(2).reset_index()
# Out:
#    Prodaja    Mesec  Trošak
# 0       70  Februar    50.0
# 1       70   Januar    30.0
# 2       80  Februar    37.5
# 3       80   Januar    40.0
# 4       90  Februar    42.5
# 5      100   Januar    40.0
# 6      110   Januar    55.0
# 7      120  Februar    60.0
# 8      130   Januar    45.0

# %% [markdown]
# # AIRBNB DATA

# %%
airbnb = pd.read_csv('airbnb_clean_final.csv')

# %%
airbnb.head()
# Out:
#    Unnamed: 0        id                                           name  \
# 0           0  12147973           Sunny Bungalow in the City of Boston
# 1           1   3075044              Charming room in pet friendly apt
# 2           2      6976               Mexican Folk Art Haven in Boston
# 3           3   1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4           4   7651065                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                          description host_name  \
# 0  Cozy, sunny, family home.  Master bedroom high...  Virginia
# 1  Charming and quiet room in a second floor 1910...    Andrea
# ...

# %%
airbnb.describe()
# Out:
#         Unnamed: 0            id     latitude    longitude  accommodates  \
# count  3585.000000  3.585000e+03  3585.000000  3585.000000   3585.000000
# mean   1792.000000  8.440875e+06    42.340032   -71.084818      3.041283
# std    1035.044685  4.500787e+06     0.024403     0.031565      1.778929
# min       0.000000  3.353000e+03    42.235942   -71.171789      1.000000
# 25%     896.000000  4.679319e+06    42.329995   -71.105083      2.000000
# 50%    1792.000000  8.577620e+06    42.345201   -71.078429      2.000000
# 75%    2688.000000  1.278953e+07    42.354685   -71.062155      4.000000
# max    3584.000000  1.493346e+07    42.389982   -71.000100     16.000000
#
#          bathrooms     bedrooms         beds        price  guests_included  \
# count  3585.000000  3585.000000  3585.000000  3585.000000      3585.000000
# mean      1.220781     1.258020     1.609205   173.925802         1.429847
# std       0.500698     0.753032     1.010754   148.331321         1.056787
# ...

# %%
airbnb['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Allston-Brighton      364
# Jamaica Plain         314
# South End             298
# Back Bay              291
# Fenway/Kenmore        249
# South Boston          216
# Dorchester            195
# Beacon Hill           174
# North End             125
# East Boston           117
# Roxbury               116
# Mission Hill          103
# Charlestown            79
# Chinatown              78
# West End               68
# Roslindale             50
# 02134                  36
# West Roxbury           35
# 02124                  35
# Theater District       33
# 02115                  31
# 02128                  28
# 02114                  27
# 02130                  26
# 02116                  26
# Downtown Crossing      26
# Hyde Park              25
# 02118                  24
# 02215                  23
# 02199                  21
# 02120                  20
# 02127                  20
# Mattapan               20
# 02135                  20
# 02210                  18
# ...

# %%
airbnb['neighbourhood'].value_counts(normalize = True)*100
# Out:
# neighbourhood
# Allston-Brighton      10.153417
# Jamaica Plain          8.758717
# South End              8.312413
# Back Bay               8.117155
# Fenway/Kenmore         6.945607
# South Boston           6.025105
# Dorchester             5.439331
# Beacon Hill            4.853556
# North End              3.486750
# East Boston            3.263598
# Roxbury                3.235704
# Mission Hill           2.873082
# Charlestown            2.203626
# Chinatown              2.175732
# West End               1.896792
# Roslindale             1.394700
# 02134                  1.004184
# West Roxbury           0.976290
# 02124                  0.976290
# Theater District       0.920502
# 02115                  0.864714
# 02128                  0.781032
# 02114                  0.753138
# 02130                  0.725244
# 02116                  0.725244
# Downtown Crossing      0.725244
# Hyde Park              0.697350
# 02118                  0.669456
# ...

# %%
airbnb['beds'].value_counts()
# Out:
# beds
# 1.0     2168
# 2.0      959
# 3.0      275
# 4.0      106
# 5.0       40
# 6.0       16
# 7.0        8
# 8.0        6
# 0.0        4
# 9.0        2
# 16.0       1
# Name: count, dtype: int64

# %%
airbnb['beds'].corr(airbnb['price'])
# Out:
# np.float64(0.3695321852080825)

# %%
airbnb['review_scores_rating'].corr(airbnb['price'])
# Out:
# np.float64(0.07112826590079666)

# %%
airbnb = airbnb.drop(index = 0)

# %%
airbnb.head()
# Out:
#    Unnamed: 0        id                                           name  \
# 1           1   3075044              Charming room in pet friendly apt
# 2           2      6976               Mexican Folk Art Haven in Boston
# 3           3   1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4           4   7651065                            Come Home to Boston
# 5           5  12386020                 Private Bedroom + Great Coffee
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
# 5  Super comfy bedroom plus your own bathroom in ...
#
#                                          description host_name  \
# 1  Charming and quiet room in a second floor 1910...    Andrea
# 2  Come stay with a friendly, middle-aged guy in ...      Phil
# ...

# %%
#airbnb.corr()

# %%
numerical_data = airbnb.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()
print(correlation_matrix)
# Out:
#                       Unnamed: 0        id  latitude  longitude  accommodates  \
# Unnamed: 0              1.000000  0.139082  0.102916  -0.029335     -0.047519
# id                      0.139082  1.000000  0.090461  -0.010524     -0.050705
# latitude                0.102916  0.090461  1.000000   0.318673      0.054216
# longitude              -0.029335 -0.010524  0.318673   1.000000      0.083919
# accommodates           -0.047519 -0.050705  0.054216   0.083919      1.000000
# bathrooms               0.058098 -0.012698 -0.019794   0.010127      0.347133
# bedrooms               -0.022420 -0.062773 -0.044127   0.016658      0.721859
# beds                   -0.030827 -0.044463 -0.011808   0.034678      0.814697
# price                  -0.046089 -0.059323  0.196766   0.165900      0.437713
# guests_included        -0.070183 -0.075790 -0.019872   0.016090      0.495420
# minimum_nights         -0.025755 -0.049293  0.020064  -0.019355     -0.038218
# ...

# %%
airbnb.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'summary', 'description', 'host_name',
#        'host_is_superhost', 'street', 'neighbourhood', 'state', 'zipcode',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'price', 'guests_included',
#        'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews',
#        'review_scores_rating', 'cancellation_policy'],
#       dtype='object')

# %%
group = airbnb.groupby('neighbourhood')['price'].mean()

# %%
group.sort_values()
# Out:
# neighbourhood
# 02212                  36.500000
# 02137                  58.200000
# 02152                  58.750000
# 02122                  66.428571
# 02121                  68.500000
# Chestnut Hill          70.750000
# Mattapan               72.000000
# 02126                  72.333333
# 02124                  76.771429
# 02136                  80.000000
# 02138                  83.333333
# 02139                  85.000000
# Somerville             93.076923
# Hyde Park              93.680000
# 02145                  95.000000
# Roslindale             96.081633
# 02163                  96.750000
# Dorchester             97.451282
# 02119                  97.500000
# 02131                  97.714286
# 02120                  99.500000
# 02125                 100.000000
# 02134                 100.416667
# 02135                 104.650000
# 02132                 104.666667
# 02128                 108.571429
# West Roxbury          111.342857
# 02130                 113.384615
# ...

# %%
group = airbnb.groupby('room_type')['price'].mean()

# %%
group
# Out:
# room_type
# Entire home/apt    227.426152
# Private room        96.041364
# Shared room         92.762500
# Name: price, dtype: float64

# %%
group = airbnb.groupby(['room_type', 'neighbourhood'])['price'].mean()

# %%
group
# Out:
# room_type        neighbourhood
# Entire home/apt  01125                 180.000000
#                  02102                 251.666667
#                  02108                 381.846154
#                  02109                 483.333333
#                  02110                 140.000000
#                  02111                 303.166667
#                  02113                 213.000000
#                  02114                 221.529412
#                  02115                 171.210526
#                  02116                 224.739130
#                  02117                 248.714286
#                  02118                 189.176471
#                  02119                 150.500000
#                  02120                 196.400000
#                  02121                 119.500000
#                  02124                 157.571429
#                  02125                 143.833333
#                  02126                  65.000000
# ...

# %%
group = airbnb.groupby(['room_type', 'neighbourhood']).agg({'price':'mean'})

# %%
group
# Out:
#                                          price
# room_type       neighbourhood
# Entire home/apt 01125               180.000000
#                 02102               251.666667
#                 02108               381.846154
#                 02109               483.333333
#                 02110               140.000000
#                 02111               303.166667
#                 02113               213.000000
#                 02114               221.529412
#                 02115               171.210526
#                 02116               224.739130
#                 02117               248.714286
#                 02118               189.176471
#                 02119               150.500000
#                 02120               196.400000
#                 02121               119.500000
#                 02124               157.571429
#                 02125               143.833333
#                 02126                65.000000
# ...

# %%
group = airbnb.groupby(['room_type', 'neighbourhood']).agg({'price':'mean'}).sort_values(['room_type', 'price'])

# %%
group.head()
# Out:
#                                     price
# room_type       neighbourhood
# Entire home/apt 02126           65.000000
#                 Chestnut Hill   90.000000
#                 02467          119.000000
#                 02121          119.500000
#                 02131          126.666667

# %%
group = airbnb.groupby(['room_type', 'neighbourhood']).agg(min_price= ('price', 'min'), max_price= ('price', 'max')).sort_values(['room_type'])

# %%
group.head()
# Out:
#                                   min_price  max_price
# room_type       neighbourhood
# Entire home/apt 01125                 180.0      180.0
#                 02467                 119.0      119.0
#                 Allston-Brighton       52.0      550.0
#                 Back Bay               97.0     1250.0
#                 Beacon Hill            99.0      849.0

# %%
airbnb.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'summary', 'description', 'host_name',
#        'host_is_superhost', 'street', 'neighbourhood', 'state', 'zipcode',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'price', 'guests_included',
#        'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews',
#        'review_scores_rating', 'cancellation_policy'],
#       dtype='object')

# %%
superhost_status = airbnb.groupby(['room_type', 'host_is_superhost'])['price'].mean()

# %%
superhost_status
# Out:
# room_type        host_is_superhost
# Entire home/apt  f                    224.637454
#                  t                    253.004785
# Private room     f                     96.749580
#                  t                     91.558511
# Shared room      f                     81.471429
#                  t                    171.800000
# Name: price, dtype: float64

# %%
superhost_status = airbnb.groupby(['room_type', 'host_is_superhost'])[['price', 'review_scores_rating']].mean()

# %%
superhost_status
# Out:
#                                         price  review_scores_rating
# room_type       host_is_superhost
# Entire home/apt f                  224.637454             91.752739
#                 t                  253.004785             96.870813
# Private room    f                   96.749580             90.614286
#                 t                   91.558511             96.978723
# Shared room     f                   81.471429             90.457143
#                 t                  171.800000             96.600000

# %%
mapping_table = pd.Series({'Shared room': 1, 'Private room': 2, 'Entire home/apt': 3})

# %%
airbnb['room_type_int'] = airbnb['room_type'].map(mapping_table)

# %%
airbnb.head()
# Out:
#    Unnamed: 0        id                                           name  \
# 1           1   3075044              Charming room in pet friendly apt
# 2           2      6976               Mexican Folk Art Haven in Boston
# 3           3   1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4           4   7651065                            Come Home to Boston
# 5           5  12386020                 Private Bedroom + Great Coffee
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
# 5  Super comfy bedroom plus your own bathroom in ...
#
#                                          description host_name  \
# 1  Charming and quiet room in a second floor 1910...    Andrea
# 2  Come stay with a friendly, middle-aged guy in ...      Phil
# ...

# %%
#airbnb.corr()

# %%
numer_col = airbnb.select_dtypes(include = 'number')

# %%
numer_col.head()
# Out:
#    Unnamed: 0        id   latitude  longitude  accommodates  bathrooms  \
# 1           1   3075044  42.286241 -71.134374             2        1.0
# 2           2      6976  42.292438 -71.135765             2        1.0
# 3           3   1436513  42.281106 -71.121021             4        1.0
# 4           4   7651065  42.284512 -71.136258             2        1.5
# 5           5  12386020  42.291690 -71.131893             2        1.0
#
#    bedrooms  beds  price  guests_included  minimum_nights  maximum_nights  \
# 1       1.0   1.0   65.0                0               2              15
# 2       1.0   1.0   65.0                1               3              45
# 3       1.0   2.0   75.0                2               1            1125
# 4       1.0   2.0   79.0                1               2              31
# 5       1.0   1.0   75.0                1               2            1125
#
#    number_of_reviews  review_scores_rating  room_type_int
# ...

# %%
numer_col.corr()
# Out:
#                       Unnamed: 0        id  latitude  longitude  accommodates  \
# Unnamed: 0              1.000000  0.139082  0.102916  -0.029335     -0.047519
# id                      0.139082  1.000000  0.090461  -0.010524     -0.050705
# latitude                0.102916  0.090461  1.000000   0.318673      0.054216
# longitude              -0.029335 -0.010524  0.318673   1.000000      0.083919
# accommodates           -0.047519 -0.050705  0.054216   0.083919      1.000000
# bathrooms               0.058098 -0.012698 -0.019794   0.010127      0.347133
# bedrooms               -0.022420 -0.062773 -0.044127   0.016658      0.721859
# beds                   -0.030827 -0.044463 -0.011808   0.034678      0.814697
# price                  -0.046089 -0.059323  0.196766   0.165900      0.437713
# guests_included        -0.070183 -0.075790 -0.019872   0.016090      0.495420
# minimum_nights         -0.025755 -0.049293  0.020064  -0.019355     -0.038218
# ...

# %% [markdown]
# ## TITANIK

# %%
titanik = pd.read_csv('titanik_clean.csv')

# %%
titanik.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
columns_to_explore = ['Survived', 'Pclass',  'Sex', 'Embarked']
for column in columns_to_explore:
    print(titanik[column].value_counts(normalize = True) *100)
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: proportion, dtype: float64
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: proportion, dtype: float64

# %%
titanik.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.758889    0.523008
# std     257.353842    0.486592    0.836071   13.002570    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
cat_col = titanik.select_dtypes(include= 'number')

# %%
cat_col.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033019 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.070657 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.329727  0.083081  0.018443
# Age             0.033019 -0.070657 -0.329727  1.000000 -0.232440 -0.180330
# SibSp          -0.057527 -0.035322  0.083081 -0.232440  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.180330  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.090632  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.090632
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
ct_titanic = pd.crosstab(index = titanik['Survived'], columns = titanik['Sex'], margins = True)

# %%
ct_titanic
# Out:
# Sex       female  male  All
# Survived
# 0             81   468  549
# 1            233   109  342
# All          314   577  891

# %%
ct_titanic.index = ['Nije preziveo', 'Preziveo', 'Ukupno']

# %%
ct_titanic
# Out:
# Sex            female  male  All
# Nije preziveo      81   468  549
# Preziveo          233   109  342
# Ukupno            314   577  891

# %%
ct_titanic = pd.crosstab(index = titanik['Survived'], columns = titanik['Pclass'], margins = True)
ct_titanic.index = ['Nije preziveo', 'Preziveo', 'Ukupno']
ct_titanic.columns = ['Prva', 'Druga', 'Treca', 'Ukupno']
ct_titanic
# Out:
#                Prva  Druga  Treca  Ukupno
# Nije preziveo    80     97    372     549
# Preziveo        136     87    119     342
# Ukupno          216    184    491     891

# %%
ct_titanic = pd.crosstab(index = titanik['Survived'], columns = titanik['Pclass'], margins = True)
ct_titanic.index = ['Nije preziveo', 'Preziveo', 'Ukupno']
ct_titanic.columns = ['Prva', 'Druga', 'Treca', 'Ukupno']
ct_titanic
# Out:
#                Prva  Druga  Treca  Ukupno
# Nije preziveo    80     97    372     549
# Preziveo        136     87    119     342
# Ukupno          216    184    491     891
